# %%
import pickle
import gzip
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import matplotlib
import math
import matplotlib.font_manager as fm
import matplotlib.ticker as mtick
font = fm.FontProperties()
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
def hide_spines(intx=False,inty=False):
    """Hides the top and rightmost axis spines from view for all active
    figures and their respective axes."""

    # Retrieve a list of all current figures.
    figures = [x for x in matplotlib._pylab_helpers.Gcf.get_all_fig_managers()]
    if (plt.gca().get_legend()):
        plt.setp(plt.gca().get_legend().get_texts(), fontproperties=font) 
    for figure in figures:
        # Get all Axis instances related to the figure.
        for ax in figure.canvas.figure.get_axes():
            # Disable spines.
            ax.spines['right'].set_color('none')
            ax.spines['top'].set_color('none')
            # Disable ticks.
            ax.xaxis.set_ticks_position('bottom')
            ax.yaxis.set_ticks_position('left')
           # ax.xaxis.set_major_formatter(mtick.FuncFormatter(lambda v,_: ("10$^{%d}$" % math.log(v,10)) ))
            for label in ax.get_xticklabels() :
                label.set_fontproperties(font)
            for label in ax.get_yticklabels() :
                label.set_fontproperties(font)
            #ax.set_xticklabels(ax.get_xticks(), fontproperties = font)
            ax.set_xlabel(ax.get_xlabel(), fontproperties = font)
            ax.set_ylabel(ax.get_ylabel(), fontproperties = font)
            ax.set_title(ax.get_title(), fontproperties = font)
            if (inty):
                ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%d'))
            if (intx):
                ax.xaxis.set_major_formatter(mtick.FormatStrFormatter('%d'))
def show(nm,a=0,b=0):
    hide_spines(a,b)
    #ax.xaxis.set_major_formatter(mtick.FuncFormatter(lambda v,_: ("10$^{%d}$" % math.log(v,10)) ))
    #plt.yticks([1,1e-2,1e-4,1e-6,1e-8,1e-10,1e-12], labels)
    #ax.yaxis.set_major_formatter(mtick.FuncFormatter(lambda v,_: ("10$^{%d}$" % math.log(v,10)) ))
    plt.savefig(nm);
    plt.show()
plt.rcParams['axes.titlesize'] = 18
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
#this line is only needed in iPython notebooks
# %matplotlib inline

# %%
x = np.linspace(-4,4,1000)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.set_xlabel(ax.get_xlabel(), fontproperties = font)
ax.set_ylabel(ax.get_ylabel(), fontproperties = font)
for label in ax.get_xticklabels() :
    label.set_fontproperties(font)
for label in ax.get_yticklabels() :
    label.set_fontproperties(font)

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.plot(x,1.0/(1+np.exp(-x)),label="$\\frac{1}{1+e^{-u}}$")
plt.plot(x,np.tanh(x),"--",label="$\\tanh(u)$")
plt.plot(x,np.arctan(x),"-.",label="$\\tan^{-1}(u)$")
plt.plot(x,x,":",label="identity")
plt.ylim(-2,2)
plt.xlabel("u")
plt.ylabel("$\\sigma(u)$")
ax.xaxis.set_label_coords(0.9, 0.55)
ax.yaxis.set_label_coords(0.48, 0.9)
plt.legend(loc="best")

if (plt.gca().get_legend()):
    plt.setp(plt.gca().get_legend().get_texts(), fontproperties=font) 
plt.savefig("sigmas.pdf")
plt.show()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.set_xlabel(ax.get_xlabel(), fontproperties = font)
ax.set_ylabel(ax.get_ylabel(), fontproperties = font)
for label in ax.get_xticklabels() :
    label.set_fontproperties(font)
for label in ax.get_yticklabels() :
    label.set_fontproperties(font)

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.plot(x,0.5*(x+np.abs(x)),label="ReLU")
plt.plot(x,np.log(1+np.exp(x)),"--",label="$\\log(1+e^u)$")
plt.xlabel("u")
plt.ylabel("$\\sigma(u)$")
ax.xaxis.set_label_coords(0.9, 0.1)
ax.yaxis.set_label_coords(0.48, 0.82)
plt.legend(loc="best")

if (plt.gca().get_legend()):
    plt.setp(plt.gca().get_legend().get_texts(), fontproperties=font) 
plt.savefig("sigmas_relu.pdf")

# %%
x = np.linspace(-4,4,1000)
func = lambda x: x**2*(1+0.5*np.cos(x*math.pi))
dfunc = lambda x: 2*x*(1+0.5*np.cos(x*math.pi)) + x**2*(-np.sin(x*math.pi)*.5*math.pi)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.set_xlabel(ax.get_xlabel(), fontproperties = font)
ax.set_ylabel(ax.get_ylabel(), fontproperties = font)
for label in ax.get_xticklabels() :
    label.set_fontproperties(font)
for label in ax.get_yticklabels() :
    label.set_fontproperties(font)

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.plot(x,func(x),label="Loss function")
eta  = 0.07
steps = 4
xs = np.zeros(steps+1)
xs[0] = 3.9
for i in range(steps):
    xs[i+1] = xs[i] - eta*dfunc(xs[i])
plt.plot(xs,func(xs),"*--",label="$\\eta = 0.07$",markersize=10)
eta  = 0.18
steps = 4
xs = np.zeros(steps+1)
xs[0] = 3.9
for i in range(steps):
    xs[i+1] = xs[i] - eta*dfunc(xs[i])
plt.plot(xs,func(xs),"o--",label="$\\eta = 0.18$",markersize=10)
plt.xlabel("w")
plt.ylabel("$L$")
eta  = .327
steps = 4
xs = np.zeros(steps+1)
xs[0] = 3.9
for i in range(steps):
    xs[i+1] = xs[i] - eta*dfunc(xs[i])
    print(xs[i],dfunc(xs[i]))
plt.plot(xs,func(xs),"^--",label="$\\eta = 0.327$",markersize=10)
plt.legend(loc="upper left")
plt.ylim(np.min(func(x)),np.max(func(x)))
plt.xlim(x[0],x[-1])
if (plt.gca().get_legend()):
    plt.setp(plt.gca().get_legend().get_texts(), fontproperties=font) 
plt.savefig("grad_descent.pdf")
# Out:
# 3.9 18.892096388304694
# -2.277715518975635 0.22182061477410908
# -2.350250860006769 1.9681441872697842
# -2.9938340092439883 -2.721685796926194

# %%
#sine NN
relu = lambda x: 0.5*(np.abs(x)+x)
layer1 = lambda x: np.array([relu(x-math.pi),relu(-x+math.pi)])
layer2 = lambda z: np.array([relu(z[0]-math.pi/2),relu(-z[0]+math.pi/2-10000*z[1]),
                             relu(z[1]-math.pi/2),relu(-z[1]+math.pi/2-1000*z[0])])
layer3 = lambda z: np.array([relu(-z[0]*0.664439 - z[1]*0.664439 + 1.15847-10000*(z[3]+z[2])),
                                  relu(-z[2]*0.664439 - z[3]*0.664439 + 1.15847-10000*(z[0]+z[1]))])
layer4 = lambda z: -z[0]+z[1]
nn = lambda x: layer4(layer3(layer2(layer1(x))))

# %%
x = math.pi-0.001
print(layer1(x))
print(layer2(layer1(x)))
print(layer3(layer2(layer1(x))))
print(nn(x))
# Out:
# [0.    0.001]
# [0.         0.         0.         1.56979633]
# [0.        0.1154361]
# 0.11543609842072566

# %%
N = 10000
x = np.linspace(0,2*math.pi,N)
vals = np.zeros(x.size)
for i in range(x.size):
    vals[i] = nn(x[i])
plt.plot(x,vals, label="DNN")
plt.plot(x,np.sin(x),'--', label="$\\sin x$")
plt.legend(loc="best")
plt.xlabel("$x_1$")
plt.ylabel("$f(x)$")
show("sin_approx.pdf")

# %%
x = math.pi*7.0/4.0
z1 = layer1(x)
print(z1)
z2 = layer2(z1)
print(z2)
z3 = layer3(z2)
print(z3)
z4 = layer4(z3)
print(z4)
# Out:
# [2.35619449 0.        ]
# [0.78539816 0.         0.         0.        ]
# [0.63662083 0.        ]
# -0.6366208297103629
